# %%
# load data

# Pages = load pages df
# Skills = load skills df

#title for webpage
st.write("""
         # Learning Spine Mapping Search
         """
         )

# Toggles

# Note: streamlit file uploader. Interesting but probably not for us

# need to select which of two df to search: search page, return skill or search skill, return page
# Return Skills or pages 

resultType = st.radio('What should this search return?',['Pages', 'Skills'], index = 1) 

# create searchResult df. this is what search returns

if resultType == 'Pages':
    searchResult = pd.copy(Pages)
else 
    searchResult = pd.copy(Skills)
    
# grade slider

# Radio Select 5 20 all: select n results to return
resultN = st.radio("How Many results?",['5','20','All'], index = 1)

if resultN == '5':
    resultL == 5
elif resultN == '20':
    resultL == 20
else resultN == 'All':
    resultL == len(searchResult)

# select search criterea

searchList = ['Skill Code','Skill Title', 'Skill Description', 'Skill GUID']

searchType = st.selectbox('Select Search Method', searchList, index = searchlist.index('Skill Code'))

# Enter Text

search = st.text_input('enter your skill code')

# set searchResult column to search with searchtype


searchResult[searchType] == search 

# use resultL to set length of results

# 

# Display Data
# st.dataframe(searchResult)

# %%
# Out:
# 4

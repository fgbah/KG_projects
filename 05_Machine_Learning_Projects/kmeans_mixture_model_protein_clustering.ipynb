# %% [markdown]
# # K-means and Mixture Model Clustering on Protein Data
#
# K-means and Gaussian Mixture Models for protein data clustering.
# Original file: K-means-mixture_Model-clustering-Protein-data.ipynb
